# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('axes', axisbelow=True)

# %% [markdown]
# # Build DataFrames / Numpy Arrays

# %%
db = pd.read_csv("../data/clean.csv")
db.describe()
# Out:
#                AQ1          AQ2          AQ3          AQ4         AOT1  \
# count  1304.000000  1304.000000  1304.000000  1304.000000  1304.000000
# mean     28.459356    28.473926    28.490031    26.944018     0.661043
# std       5.946541     5.849685     5.761296     5.934725     2.766450
# min       9.000000    11.000000    10.000000    10.000000     0.000000
# 25%      25.000000    25.000000    24.000000    23.000000     0.000000
# 50%      28.000000    28.000000    28.000000    27.000000     0.000000
# 75%      32.000000    33.000000    33.000000    31.000000     0.000000
# max      55.000000    47.000000    51.000000    48.000000    20.000000
#
#               AOT2           AT          HQ1          HQ2          HQ3  \
# count  1304.000000  1304.000000  1304.000000  1304.000000  1304.000000
# mean      0.064417   113.092791    29.378067    29.006135    29.160276
# std       0.773996    12.011435     5.878967     5.924438     5.999073
# min       0.000000    79.000000    12.000000    11.000000    10.000000
# 25%       0.000000   105.000000    25.000000    25.000000    25.000000
# 50%       0.000000   113.000000    29.000000    29.000000    29.000000
# 75%       0.000000   121.000000    33.000000    33.000000    33.000000
# max      12.000000   176.000000    50.000000    50.000000    51.000000
#
#                HQ4         HOT1         HOT2           HT
# count  1304.000000  1304.000000  1304.000000  1304.000000
# mean     27.427914     0.693252     0.080521   115.746166
# std       5.782926     2.821812     0.964666    11.945803
# min      10.000000     0.000000     0.000000    80.000000
# 25%      23.750000     0.000000     0.000000   108.000000
# 50%      28.000000     0.000000     0.000000   116.000000
# 75%      31.000000     0.000000     0.000000   124.000000
# max      49.000000    20.000000    16.000000   175.000000

# %%
np_array = db.to_numpy()
np_array
# Out:
# array([[ 29,  34,  25, ...,   0,   0, 126],
#        [ 22,  30,  19, ...,   0,   0, 123],
#        [ 28,  27,  28, ...,   0,   0, 113],
#        ...,
#        [ 31,  19,  21, ...,   0,   0,  96],
#        [ 26,  20,  31, ...,   0,   0, 122],
#        [ 29,  23,  10, ...,   0,   0, 112]], dtype=int64)

# %%
db_team = pd.read_csv("../data/teams.csv")
db_team.head()
# Out:
#                  Away                   Home
# 0  Philadelphia 76ers         Boston Celtics
# 1  Los Angeles Lakers  Golden State Warriors
# 2       Orlando Magic        Detroit Pistons
# 3  Washington Wizards         Indiana Pacers
# 4     Houston Rockets          Atlanta Hawks

# %%
np_team = db_team.to_numpy()
np_team
# Out:
# array([['Philadelphia 76ers', 'Boston Celtics'],
#        ['Los Angeles Lakers', 'Golden State Warriors'],
#        ['Orlando Magic', 'Detroit Pistons'],
#        ...,
#        ['New York Knicks', 'Miami Heat'],
#        ['Golden State Warriors', 'Los Angeles Lakers'],
#        ['Philadelphia 76ers', 'Boston Celtics']], dtype=object)

# %% [markdown]
# # Making Dictionary of Totals

# %%
#build dict
d_teams_totals = {}
d_teams_totals["Home"] = {}
d_teams_totals["Away"] = {}
for idx, sample in enumerate(np_array):
    try:
        d_teams_totals["Away"][np_team[idx][0]].append(sample[6])
    except:
        d_teams_totals["Away"][np_team[idx][0]] = [sample[6]]
    try:
        d_teams_totals["Home"][np_team[idx][1]].append(sample[-1])
    except:
        d_teams_totals["Home"][np_team[idx][1]] = [sample[-1]]
    
d_teams_totals["Home"]["Charlotte Hornets"][0]
# Out:
# 112

# %% [markdown]
# ## Hornets Figure

# %%
hornets_h = d_teams_totals["Home"]["Charlotte Hornets"]
hornets_a = d_teams_totals["Away"]["Charlotte Hornets"]

bins_t = [x for x in range(min(hornets_h) - 10, max(hornets_h) + 9, 10)]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
ax1.hist(hornets_h, bins=bins_t, color=['seagreen'])
ax2.hist(hornets_a, bins=bins_t, color=['seagreen'])
ax1.axvline(np.array(hornets_h).mean(), color='k', linestyle='dashed')
ax2.axvline(np.array(hornets_a).mean(), color='k', linestyle='dashed')
fig.suptitle("Distribution of Charlotte Hornets game scores Home / Away")
ax1.grid()
ax2.grid()

# %%
basic_dict = {}
for idx, sample in enumerate(d_teams_totals["Home"]):
    basic_dict[sample] = d_teams_totals["Home"][sample]
    basic_dict[sample].extend(d_teams_totals["Away"][sample])

# %%
min_t = 'Charlotte Hornets'
max_t = 'Charlotte Hornets'

means = {}

for sample in basic_dict:
    means[sample] = float(np.array(basic_dict[sample]).mean())
    print(sample + ": " + str(means[sample]))
    
for sample in means:
    if means[max_t] < means[sample]:
        max_t = sample
    if means[min_t] > means[sample]:
        min_t = sample

print()
print("Max: " + max_t)
print("Min: " + min_t)
# Out:
# Boston Celtics: 117.61052631578947
# Golden State Warriors: 118.13684210526316
# Detroit Pistons: 110.3048780487805
# Indiana Pacers: 116.28048780487805
# Atlanta Hawks: 118.2247191011236
# Brooklyn Nets: 112.38372093023256
# Memphis Grizzlies: 116.07954545454545
# Miami Heat: 109.78947368421052
# Toronto Raptors: 112.75903614457832
# Minnesota Timberwolves: 115.08988764044943
# San Antonio Spurs: 113.03658536585365
# Utah Jazz: 117.07317073170732
# Phoenix Suns: 113.70967741935483
# Sacramento Kings: 120.15730337078652
# Philadelphia 76ers: 113.72043010752688
# Los Angeles Lakers: 116.47368421052632
# Charlotte Hornets: 110.95121951219512
# Washington Wizards: 113.15853658536585
# New York Knicks: 114.13978494623656
# Houston Rockets: 110.7439024390244
# Portland Trail Blazers: 113.40243902439025
# Orlando Magic: 111.41463414634147
# Chicago Bulls: 112.80952380952381
# Milwaukee Bucks: 117.04597701149426
# Dallas Mavericks: 114.21951219512195
# Denver Nuggets: 115.79569892473118
# Cleveland Cavaliers: 111.2183908045977
# New Orleans Pelicans: 114.40963855421687
# Oklahoma City Thunder: 117.27380952380952
# Los Angeles Clippers: 113.70114942528735
#
# Max: Sacramento Kings
# Min: Miami Heat

# %%
fig, axs = plt.subplots(10, 3, figsize = (15, 50))

axs = axs.ravel()
fig.patch.set_facecolor("white")

for idx, sample in enumerate(basic_dict):
    if sample == max_t:
        axs[idx].hist(basic_dict[sample], bins = bins_t, color='seagreen')
    elif sample == min_t:
        axs[idx].hist(basic_dict[sample], bins = bins_t, color='firebrick')
    else:
        axs[idx].hist(basic_dict[sample], bins = bins_t)
    axs[idx].axvline(np.array(basic_dict[sample]).mean(), color='k', linestyle='dashed')
    axs[idx].set_title(sample + ": " + str(round(means[sample], 3)))
    axs[idx].grid()

# %% [markdown]
# # Opposing Scores

# %%
d_teams_totals_o = {}
d_teams_totals_o["Home"] = {}
d_teams_totals_o["Away"] = {}
for idx, sample in enumerate(np_array):
    try:
        d_teams_totals_o["Away"][np_team[idx][0]].append(sample[-1])
    except:
        d_teams_totals_o["Away"][np_team[idx][0]] = [sample[-1]]
    try:
        d_teams_totals_o["Home"][np_team[idx][1]].append(sample[6])
    except:
        d_teams_totals_o["Home"][np_team[idx][1]] = [sample[6]]
        
d_teams_totals_o["Home"]["Charlotte Hornets"][0]
# Out:
# 124

# %%
hornets_h_o = d_teams_totals_o["Home"]["Charlotte Hornets"]
hornets_a_o = d_teams_totals_o["Away"]["Charlotte Hornets"]

bins_t = [x for x in range(min(hornets_h) - 10, max(hornets_h) + 9, 10)]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
ax1.hist(hornets_h_o, bins=bins_t, color=['seagreen'])
ax2.hist(hornets_a_o, bins=bins_t, color=['seagreen'])
ax1.axvline(np.array(hornets_h_o).mean(), color='k', linestyle='dashed')
ax2.axvline(np.array(hornets_a_o).mean(), color='k', linestyle='dashed')
fig.suptitle("Distribution of Charlotte Hornets Opp game scores Home / Away")
ax1.grid()
ax2.grid()

# %%
basic_dict_o = {}
for idx, sample in enumerate(d_teams_totals_o["Home"]):
    basic_dict_o[sample] = d_teams_totals_o["Home"][sample]
    basic_dict_o[sample].extend(d_teams_totals_o["Away"][sample])

# %%
fig, ax = plt.subplots()
fig.suptitle("Charlotte Hornets Totals vs. Charlotte Hornets Oppenent Totals")

o_heights, o_bins = np.histogram(basic_dict_o["Charlotte Hornets"])
h_heights, h_bins = np.histogram(basic_dict["Charlotte Hornets"], bins=o_bins)

width = (o_bins[1] - o_bins[0])/3
fig.patch.set_facecolor("white")

ax.bar(o_bins[:-1], o_heights, width=width, facecolor='firebrick', label="Opp")
ax.bar(h_bins[:-1]+width, h_heights, width=width, facecolor='seagreen', label="Hornets")
ax.legend()
ax.grid()
